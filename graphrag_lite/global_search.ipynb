# %%
# Code modified from Microsoft/GraphRAG project

# %%
api_key = "sk-"
llm_model = "gpt-4o"

# %%
import pandas as pd
import tiktoken

from graphrag.query.indexer_adapters import read_indexer_entities, read_indexer_reports
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch

# %% [markdown]
# ### LLM setup

# %%
llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

# %%
COMMUNITY_LEVEL = 2

entity_df = pd.read_parquet("data/create_final_nodes.parquet")
report_df = pd.read_parquet("data/create_final_community_reports.parquet")
entity_embedding_df = pd.read_parquet("data/create_final_entities.parquet")

reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
print(f"Report records: {len(report_df)}")
report_df.head()
# Out:
# Report records: 31
#   community                                       full_content  level  rank  \
# 0        30  # Scrooge and His Community\n\nThe community c...      2   8.5
# 1        31  # Scrooge's Journey with The Spirit\n\nThe com...      2   7.5
# 2        16  # A Christmas Carol and Its Contributors\n\nTh...      1   7.5
# 3        17  # J. B. Lippincott Company and A Christmas Car...      1   6.5
# 4        18  # Project Gutenberg and A Christmas Carol\n\nT...      1   3.0
#
#                                             title  \
# 0                       Scrooge and His Community
# 1               Scrooge's Journey with The Spirit
# 2          A Christmas Carol and Its Contributors
# 3  J. B. Lippincott Company and A Christmas Carol
# 4         Project Gutenberg and A Christmas Carol
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The impact severity rating is high due to the ...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is moderately high ...
# 4  The impact severity rating is low due to the p...
#
#                                              summary  \
# 0  The community centers around Scrooge, a comple...
# 1  The community revolves around Scrooge and his ...
# 2  The community revolves around the novella 'A C...
# 3  The community centers around J. B. Lippincott ...
# 4  The community revolves around Project Gutenber...
#
#                                             findings  \
# 0  [{'explanation': 'Scrooge is the central figur...
# 1  [{'explanation': 'The Spirit is a supernatural...
# 2  [{'explanation': 'Charles Dickens is the autho...
# 3  [{'explanation': 'J. B. Lippincott Company is ...
# 4  [{'explanation': 'Project Gutenberg is a signi...
#
#                                    full_content_json  \
# 0  {\n    "title": "Scrooge and His Community",\n...
# 1  {\n    "title": "Scrooge's Journey with The Sp...
# 2  {\n    "title": "A Christmas Carol and Its Con...
# 3  {\n    "title": "J. B. Lippincott Company and ...
# 4  {\n    "title": "Project Gutenberg and A Chris...
#
#                                      id
# 0  4bf0a5b9-d843-44bd-923d-12856108186a
# 1  b6e474fd-a19a-4f5b-b1c4-022a4e3fac7a
# 2  b632ef4f-938c-4e95-a07f-2b10dabf2716
# 3  ed7baee5-b820-43fb-a1d8-e5da5ad3f3d4
# 4  4289cf6e-0e88-4c6f-90c2-05e6c8c22f95

# %% [markdown]
# #### Build global context based on community reports

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    entities=entities,  # default to None if you don't want to use community weights for ranking
    token_encoder=token_encoder,
)

# %% [markdown]
# #### Perform global search

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 2000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000-1500)
    "temperature": 0.0,
}

# %%
search_engine = GlobalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
result = await search_engine.asearch(
    "What are the top themes in this story?"
)

print(result.response)
# Out:
# ### Top Themes in the Story
#
# #### Redemption and Transformation
# The central theme of the story is the redemption and transformation of Ebenezer Scrooge. Initially depicted as a miserly and solitary figure, Scrooge undergoes a profound emotional and spiritual transformation. This change is catalyzed by his interactions with various supernatural figures, including the ghost of his former business partner Jacob Marley and the Ghosts of Christmas Past, Present, and Yet to Come. These encounters prompt Scrooge to reflect on his life and ultimately embrace kindness and community [Data: Reports (19, 27, 31, 30, 12, 6, +more)].
#
# #### Impact of Supernatural Encounters
# The supernatural elements in the story play a pivotal role in Scrooge's transformation. The ghostly visitations serve as catalysts for his reflection and change. Marley's ghost and the three spirits guide Scrooge through scenes of his past, present, and potential future, highlighting the consequences of his actions and urging him to reconsider his values [Data: Reports (30, 8, 6, 19, 31)].
#
# #### Kindness and Generosity
# The theme of kindness and generosity is highlighted through characters like Fezziwig and the Cratchit family. Fezziwig is remembered fondly for his ability to make his apprentices happy through small acts of kindness, while the Cratchit family celebrates Christmas Eve with joy despite their modest means. These examples contrast sharply with Scrooge's initial focus on material wealth and underscore the positive impact of kindness and generosity on individuals and communities [Data: Reports (23, 2, 30, 6)].
#
# #### Consequences of Greed and Materialism
# Scrooge's initial focus on money and material wealth is a significant theme in the story. The Counting-House, where Scrooge and Marley conducted their business, symbolizes this focus. The ghostly visitations reveal the negative impact of such values on Scrooge's life and relationships, ultimately leading him to understand the emptiness of a life driven by greed [Data: Reports (27, 21)].
#
# #### Family and Human Connection
# The importance of family and human connection is another key theme. Scrooge's relationships with his nephew Fred and the Cratchit family highlight the value of familial bonds and social connections. Fred's invitation to Scrooge for Christmas dinner and the close-knit nature of the Cratchit family serve as reminders of the joy and fulfillment that come from being part of a loving community [Data: Reports (27, 2, 30, 25)].
#
# #### Reflection and Self-Awareness
# Scrooge's journey with the Ghosts emphasizes the theme of reflection and self-awareness. By guiding him through scenes of his past, present, and potential future, the Ghosts prompt Scrooge to reconsider his values and actions. This reflection is crucial to his eventual transformation and redemption [Data: Reports (19, 31)].
#
# ### Conclusion
# The story masterfully weaves together these themes to illustrate the profound impact of personal transformation, the importance of kindness and generosity, and the value of family and community. Through Scrooge's journey, the narrative underscores the potential for redemption and the enduring power of human connection.

# %%
# inspect the data used to build the context for the LLM responses
result.context_data["reports"]
# Out:
#     id                                              title  occurrence weight  \
# 0   19              Scrooge and the Ghost of Jacob Marley           0.260274
# 1   23                       Fezziwig's Festive Community           0.164384
# 2   27        Ebenezer Scrooge and Jacob Marley Community           0.136986
# 3    2           Bob Cratchit and Christmas Eve Community           0.123288
# 4   31                  Scrooge's Journey with The Spirit           0.109589
# 5   28                         Marley's Ghost and Scrooge           0.095890
# 6   20                    Scrooge and Christmas Community           0.082192
# 7   29                    Scrooge's Family and Associates           0.068493
# 8   24                   Fezziwig's Dance and Festivities           0.041096
# 9   13  Scrooge's Vision: The Fair Young Girl and The Man           0.027397
# 10   5                 City of London and The Corporation           0.027397
# 11  21                 Scrooge's Counting-House Community           0.027397
# 12  17     J. B. Lippincott Company and A Christmas Carol           0.027397
# 13  15                    Scrooge's Narrative Connections           0.027397
# 14  18            Project Gutenberg and A Christmas Carol           0.027397
# 15   3           Scrooge and the Christmas Carol Incident           0.013699
# 16  10          Scrooge and Marley's Business Partnership           0.013699
# 17  11                            Scrooge and Marley Firm           0.013699
# 18  26  The Three Miss Fezziwigs and Their Romantic Im...           0.013699
# 19  14     Scrooge and the Old Ghost in a White Waistcoat           0.013699
# 20  30                          Scrooge and His Community           1.000000
# 21   8               Scrooge and Marley's Haunting Legacy           0.123288
# 22  25           Fezziwig's Ball and Domestic Festivities           0.123288
# 23  12  Scrooge's Journey through The City and The War...           0.082192
# 24   6                Jacob and the Path to Enlightenment           0.068493
# 25   9                The Schoolmaster and Master Scrooge           0.041096
#
#                                               content  rank
# 0   # Scrooge and the Ghost of Jacob Marley\n\nThe...   8.5
# 1   # Fezziwig's Festive Community\n\nThe communit...   7.5
# 2   # Ebenezer Scrooge and Jacob Marley Community\...   8.5
# 3   # Bob Cratchit and Christmas Eve Community\n\n...   7.5
# 4   # Scrooge's Journey with The Spirit\n\nThe com...   7.5
# 5   # Marley's Ghost and Scrooge\n\nThe community ...   7.5
# 6   # Scrooge and Christmas Community\n\nThe commu...   7.5
# 7   # Scrooge's Family and Associates\n\nThe commu...   7.5
# 8   # Fezziwig's Dance and Festivities\n\nThe comm...   6.5
# 9   # Scrooge's Vision: The Fair Young Girl and Th...   7.5
# 10  # City of London and The Corporation\n\nThe co...   6.5
# 11  # Scrooge's Counting-House Community\n\nThe co...   6.5
# 12  # J. B. Lippincott Company and A Christmas Car...   6.5
# 13  # Scrooge's Narrative Connections\n\nThe commu...   4.5
# 14  # Project Gutenberg and A Christmas Carol\n\nT...   3.0
# 15  # Scrooge and the Christmas Carol Incident\n\n...   6.5
# 16  # Scrooge and Marley's Business Partnership\n\...   6.5
# 17  # Scrooge and Marley Firm\n\nThe community rev...   6.5
# 18  # The Three Miss Fezziwigs and Their Romantic ...   4.5
# 19  # Scrooge and the Old Ghost in a White Waistco...   4.5
# 20  # Scrooge and His Community\n\nThe community c...   8.5
# 21  # Scrooge and Marley's Haunting Legacy\n\nThe ...   8.5
# 22  # Fezziwig's Ball and Domestic Festivities\n\n...   4.5
# 23  # Scrooge's Journey through The City and The W...   7.5
# 24  # Jacob and the Path to Enlightenment\n\nThe c...   7.5
# 25  # The Schoolmaster and Master Scrooge\n\nThe c...   6.5

# %%
# inspect number of LLM calls and tokens
print(f"LLM calls: {result.llm_calls}. LLM tokens: {result.prompt_tokens}")
# Out:
# LLM calls: 3. LLM tokens: 18952
